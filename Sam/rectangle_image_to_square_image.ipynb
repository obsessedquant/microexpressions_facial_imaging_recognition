# %% [markdown]
# # Resize rectangle image to square
#
# This notebook is meant to be able convert rectangular images to square sizes.

# %%
from PIL import Image

def make_square(im, min_size=256, fill_color=(0, 0, 0, 0)):
    x, y = im.size
    size = max(min_size, x, y)
    new_im = Image.new('RGBA', (size, size), fill_color)
    new_im.paste(im, (int((size - x) / 2), int((size - y) / 2)))
    return new_im

# %%
new_image.save('./Inputs/happy1.png')

# %%
test_image = Image.open('./Inputs/how-to-be-happy.jpg')
new_image = make_square(test_image)
# new_image.show()
new_image
# Out:
# <PIL.Image.Image image mode=RGBA size=1024x1024 at 0x26505195160>

# %%
new_image = make_square(test_image, fill_color=(255, 255, 255, 0))
